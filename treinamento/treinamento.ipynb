# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.yaml')

# %%
results = model.train(
    data=r'data\config.yaml',
    epochs=300,
    patience=50,
    batch=4,
    imgsz=640,
    pretrained=False
)
